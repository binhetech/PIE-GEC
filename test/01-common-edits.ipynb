# %%
import pickle

# %% [markdown]
# # bea-2019

# %%
base="bea"
path_multitoken_inserts=open(f"../pickles/{base}/common_multitoken_inserts.p", "rb")
multitoken_inserts = pickle.load(path_multitoken_inserts)
print(f"{len(multitoken_inserts)} multitoken_inserts={multitoken_inserts}")
# Out:
# 67 multitoken_inserts=['` `', "' s", 'in the', 'lot of', 'of the', 'on the', 'want to', 'in a', "I 'm", 'to the', 'has been', 'at the', "do n't", 'able to', 'it is', 'had a', 'it was', 'for a', 'on a', "'ve been", 'for the', 'for me', 'is a', 'have a', 'have to', 'to a', 'to be', 'I am', 'at a', 'every day', 'and I', 'I will', 'as a', 'However ,', 'So ,', 'I have', 'had to', 'of a', 'in order', 'going to', "' d", 'will be', "it '", 'I was', ', and', 'that I', 'Also ,', 'This is', "It '", ', the', 'ho ##bb', 'I think', 'has a', 'to me', 'to do', 'to go', 'was a', 'in my', 'be a', 'kind of', 'had been', ', it', 'as well', 'in Japan', 'about it', 'have been', '. .']

# %%
path_inserts=open(f"../pickles/{base}/common_inserts.p", "rb")
inserts = pickle.load(path_inserts)
print(f"{len(inserts)} inserts={inserts}")
# Out:
# 933 inserts=['the', 'a', ',', 'to', '.', 'in', 'was', 'I', 'it', 'for', 'is', 'have', 'that', 'my', 'of', 'and', 'an', 'on', 'are', 'at', 'The', 'will', 'with', 'had', 'about', '##s', 'be', 'English', 'has', 'It', 'were', 'do', "'", 'this', 'from', "n't", 'would', 'am', 'so', "'m", 's', 'can', 'because', 'as', 'them', 'been', 'by', 'could', '`', '-', 'did', 'people', 'they', 'their', 'there', 'My', 'me', 'not', 'like', 'get', 'you', 'very', 'but', ')', 'some', 'more', 'This', '?', 'time', '(', 'Japanese', 'one', 'go', 'we', 'when', "'ve", 'which', 'if', 'also', 'friends', 'went', 'studying', ';', 'or', 'other', 'work', 'got', 'In', 'all', 'only', 'A', '##ing', 'things', 'We', 'any', 'now', ':', 'out', 'our', 'going', 'what', 'make', 'just', 'should', 'who', 'They', 'does', 'writing', 'much', 'these', 'So', 'really', 'made', 'too', "'ll", 'But', 'up', 'many', 'feel', 'her', '!', 'during', 'being', 'into', 'he', 'think', 'still', 'good', 'while', 'your', 'since', 'started', 'become', '
# ...

# %%
path_deletes=open(f"../pickles/{base}/common_deletes.p", "rb")
deletes = pickle.load(path_deletes)
print(f"{len(deletes)} deletes={deletes}")
# Out:
# 1000 deletes={'the': 46902, ',': 39119, 'to': 35823, 'a': 33384, 'in': 25546, 'of': 24718, 'is': 24293, '.': 17705, 'it': 16214, 'for': 14719, 'that': 14037, 'have': 12404, 'and': 12288, 's': 12145, "'": 12123, 'I': 11888, 'was': 11095, 'my': 9728, '##s': 9426, 'on': 8927, 'be': 8702, 'are': 8253, 'at': 8079, 'so': 7680, 'do': 7585, 'with': 6944, 'this': 6321, 'had': 5822, 'me': 5286, 'by': 5282, 'It': 5267, 'can': 5183, '`': 5000, 'as': 4907, 'go': 4745, 'from': 4665, 'not': 4653, 'en': 4607, 'about': 4471, 'has': 4323, 'time': 4208, 'one': 4204, '##sh': 4195, '##gli': 4144, 'will': 4005, 'The': 3882, '-': 3876, 'an': 3764, 'which': 3756, '##ed': 3695, '##ing': 3605, '##d': 3598, 'get': 3572, 'there': 3526, 'make': 3526, 'like': 3518, 'more': 3451, 'could': 3388, 'but': 3351, 'you': 3310, 'we': 3304, '##t': 3272, 'am': 3235, 'much': 3172, 'some': 3165, 'were': 3059, "n't": 2984, '##y': 2963, "'m": 2924, 'got': 2897, 'would': 2854, '##e': 2783, 'been': 2774, 'all': 2744, 'very': 2686
# ...

# %% [markdown]
# # conll

# %%
base="conll"
path_multitoken_inserts=open(f"../pickles/{base}/common_multitoken_inserts.p", "rb")
multitoken_inserts = pickle.load(path_multitoken_inserts)
print(f"{len(multitoken_inserts)} multitoken_inserts={multitoken_inserts}")
# Out:
# 68 multitoken_inserts=['` `', "' s", 'in the', 'lot of', 'of the', 'on the', 'want to', 'in a', "I 'm", 'to the', 'has been', 'at the', "do n't", 'able to', 'it is', 'had a', 'it was', 'on a', 'for a', "'ve been", 'for me', 'for the', 'have a', 'is a', 'to a', 'have to', 'I am', 'to be', 'at a', 'and I', 'every day', 'I will', 'as a', 'I have', 'So ,', 'However ,', 'in order', "' d", 'of a', 'had to', 'going to', 'I was', "it '", 'will be', 'that I', ', and', "It '", 'ho ##bb', 'This is', 'I think', 'to me', 'Also ,', 'has a', 'to do', 'in my', 'was a', 'to go', 'be a', 'kind of', 'as well', 'in Japan', ', the', 'about it', '. .', 'have been', 'of my', 'It was', 'so I']

# %%
path_inserts=open(f"../pickles/{base}/common_inserts.p", "rb")
inserts = pickle.load(path_inserts)
print(f"{len(inserts)} inserts={inserts}")
# Out:
# 932 inserts=['the', 'a', ',', 'to', '.', 'in', 'was', 'I', 'it', 'for', 'is', 'my', 'that', 'have', 'and', 'of', 'an', 'are', 'on', 'The', 'at', 'will', 'with', 'had', 'about', '##s', 'be', 'English', 'has', 'were', 'It', 'do', 'this', "'", "n't", 'from', 'am', 'would', 'so', "'m", 's', 'can', 'because', 'as', 'them', 'been', '`', 'by', 'could', 'did', 'people', '-', 'me', 'they', 'their', 'My', 'there', 'not', 'like', 'get', 'very', ')', 'some', 'but', 'you', 'more', 'This', '?', 'time', '(', 'Japanese', 'one', "'ve", 'when', 'we', 'go', 'if', 'friends', 'which', 'also', 'studying', 'went', 'or', 'other', 'work', ';', 'only', 'all', 'got', '##ing', 'A', 'now', 'any', 'things', ':', 'out', 'our', 'what', 'going', 'We', 'In', 'just', 'make', 'writing', 'does', 'should', 'who', 'much', 'So', 'They', 'really', 'these', "'ll", 'made', 'too', 'But', 'up', 'feel', '!', 'many', 'during', 'her', 'still', 'think', 'he', 'being', 'good', 'while', 'since', 'into', 'started', 'your', 'become', '
# ...

# %%
path_deletes=open(f"../pickles/{base}/common_deletes.p", "rb")
deletes = pickle.load(path_deletes)
print(f"{len(deletes)} deletes={deletes}")
# Out:
# 500 deletes={'the': 44116, ',': 36501, 'to': 34501, 'a': 32498, 'in': 24139, 'of': 23712, 'is': 23652, '.': 17416, 'it': 15493, 'for': 14031, 'that': 13573, 'and': 12152, 'have': 11945, 'I': 11810, 's': 11799, "'": 11766, 'was': 10836, 'my': 9561, '##s': 9024, 'on': 8408, 'be': 8399, 'are': 7836, 'at': 7809, 'so': 7552, 'do': 7282, 'with': 6589, 'this': 6093, 'had': 5636, 'me': 5211, 'It': 5203, 'by': 5080, '`': 5000, 'can': 4928, 'as': 4664, 'go': 4608, 'en': 4559, 'not': 4556, 'from': 4490, 'about': 4280, '##sh': 4182, '##gli': 4133, 'has': 4124, 'time': 4107, 'one': 4074, 'will': 3758, '-': 3744, 'The': 3728, 'which': 3668, '##ed': 3608, 'an': 3605, '##d': 3511, '##ing': 3507, 'get': 3432, 'like': 3424, 'there': 3393, 'make': 3348, 'more': 3296, 'but': 3262, 'could': 3235, '##t': 3178, 'am': 3145, 'we': 3131, 'you': 3121, 'some': 3098, 'much': 3034, "n't": 2940, 'were': 2928, "'m": 2879, '##y': 2874, 'got': 2838, '##e': 2693, 'And': 2678, 'would': 2660, 'been': 2645, 'very': 2634,
# ...

# %% [markdown]
# # common

# %%
path_inserts=open("../errorify/common_inserts.p", "rb")
common_inserts = pickle.load(path_inserts)
print(f"{len(common_inserts)} common_inserts={common_inserts}")
# Out:
# 392 common_inserts={',': 32565, 'My': 514, 'would': 1782, 'a': 33100, 'that': 5049, 'to': 11020, 'the': 38196, 'in': 4830, 'for': 4363, 'The': 4583, 'so': 1520, "n't": 192, 'only': 890, "'ve": 1315, '.': 7782, 'of': 3734, '(': 1943, ')': 1704, 'on the': 249, 'an': 4959, 'with': 2017, 'it': 5262, "'m": 1355, "I 'm": 566, 'enough': 158, ';': 320, 'had': 1767, 'working': 83, '``': 4049, '( the )': 117, 'will': 4183, 'They': 98, 'more': 1144, "'ll": 894, 'was': 3388, 'there': 897, 'also': 1356, 'skills': 143, 'has': 1424, 'been': 961, 'by': 934, 'writing': 91, 'work': 158, 'my': 4616, "'s": 2478, 'but': 950, 'one': 473, 'do': 1377, 'have': 4468, 'use': 119, 'made': 131, 'in the': 627, 'there are': 116, 'is': 4121, 'can': 1148, ':': 385, 'then': 577, 'and': 4499, 'going': 175, 'too': 564, 'at': 2221, 'them': 753, 'because': 703, 'time': 493, 'found': 125, '. It': 83, 'it is': 455, 'being': 523, 'if': 912, '-': 1711, 'while': 278, 'much': 313, 'be': 2061, 'their': 796, 'am': 2037, 'anymore
# ...

# %%
path_deletes=open("../errorify/common_deletes.p", "rb")
common_deletes = pickle.load(path_deletes)
print(f"{len(common_deletes)} common_deletes={common_deletes}")
# Out:
# 488 common_deletes={'like': 1352, 'had': 2130, 'At': 486, 'first': 471, 'he': 659, 'is': 6447, 'picture': 77, 'You': 80, 'do': 2164, 'a': 17717, "'s": 4015, 'does': 251, '-': 2676, '.': 9376, 'the': 24966, 'there': 1335, 'who': 980, 'not': 1612, 'want': 350, 'in': 9822, 'very': 1266, 'many': 408, 'try': 114, 'so': 2693, 'Because': 468, 'am': 794, ',': 21064, 'to': 19255, 'help': 130, 'up': 1270, 'by': 1682, 'sentence': 82, 'of': 12330, 'be': 3517, 'again': 382, 'some': 1211, 'them': 831, 'keep': 138, '2': 127, 'are': 2005, 'get': 733, 'was': 3569, 'problem': 118, 'on': 3269, 'say': 266, 'did': 599, 'having': 212, 'at': 2864, 'come': 437, 'and': 4939, 'just': 1112, 'has': 1034, 'next': 233, 'Especially': 398, 'it': 6076, "'m": 971, 'buy': 101, 'an': 1396, 'diary': 114, "n't": 880, 'with': 2391, 'never': 119, 'I': 6800, 'big': 158, 'A': 311, 'look': 126, 'high': 139, 'as': 2297, 'We': 92, 'often': 196, 'english': 164, 'It': 931, 'me': 2537, 'can': 1456, 'work': 456, 'My': 134, 'will': 
# ...

# %%
path_replaces=open("../errorify/common_replaces.p", "rb")
common_replaces = pickle.load(path_replaces)
print(f"{len(common_replaces)} common_replaces={common_replaces}")
# Out:
# 1585 common_replaces={'equipment': defaultdict(<class 'int'>, {'equipments': 97, 'material': 14, 'tecnology': 1, 'the': 1, 'stuffs': 1, 'information': 1, 'equipmet': 1, 'photography': 1, 'euipment': 1, 'equiment': 2, 'necessary': 1, 'equippments': 1, 'facilities': 1, 'brad': 1, 'equepument': 2, 'concerts': 1, 'Equipment': 1, 'equitments': 1, 'equipement': 4, 'gears': 1, 'equiptment': 1, 'equipements': 1, 'furnitures': 1, 'aquitment': 1, 'device': 1, 'merchandise': 1, 'enquipment': 1, 'in': 1, 'kits': 1, 'goods': 1, 'materials': 1}), 'Therefore': defaultdict(<class 'int'>, {'first': 1, 'After': 1, 'So': 58, 'that': 3, 'Therefor': 42, 'Then': 11, 'therefore': 56, 'until': 1, 'such': 2, 'Hence': 2, 'Thereforel': 1, 'Thereafter': 1, 'Thereby': 9, 'Therefofe': 1, 'feel': 1, 'therfore': 1, 'so': 13, 'Thus': 6, 'conclude': 3, 'There': 8, 'airplane': 1, 'And': 3, 'I': 1, 'Finally': 1, 'there': 1, 'meaning': 1, 'Terefore': 3, 'Consequently': 1, 'Theerefore': 1, 'Therfore': 7, 'disagree': 1, '
# ...
